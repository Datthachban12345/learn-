# %%
import tkinter as tk
 
 
def on_configure(event):
    # update scrollregion after starting 'mainloop'
    # when all widgets are in canvas
    canvas.configure(scrollregion=canvas.bbox('all'))
 
 
root = tk.Tk()
 
# --- create canvas with scrollbar ---
 
canvas = tk.Canvas(root)
canvas.pack(side=tk.LEFT)
 
scrollbar = tk.Scrollbar(root, command=canvas.yview)
scrollbar.pack(side=tk.LEFT, fill='y')
 
canvas.configure(yscrollcommand = scrollbar.set)
 
# update scrollregion after starting 'mainloop'
# when all widgets are in canvas
canvas.bind('<Configure>', on_configure)
 
# --- put frame in canvas ---
 
frame = tk.Frame(canvas)
canvas.create_window((0,0), window=frame, anchor='nw')
 
# --- add widgets in frame ---
 

 
# --- start program ---
 
root.mainloop()

# %%
from tkinter import *
import os
import random

def pronoun(word1):
    try:
        f=open('pronoun.txt','a',encoding='utf8')
        f.write(word1+"\n")
        f.close()
    except:
        pass
def English1(word):
    try:
        f=open('English.txt','a')
        f.write(word+"\n")
        f.close()
    except:
        pass
def VietNam1(Tu):
    try:
        f=open('Vietnamese.txt','a',encoding='utf8')
        f.write(Tu+"\n")
        f.close()
    except:
        pass
def Fusion(Nghia):
    try:
        f=open('Anh_Viet.txt','a',encoding='utf8')
        f.write(Nghia+"\n")
        f.close()
    except:
        pass

    
def read():
    hc=[]
    try:
        f=open('Anh_Viet.txt','r',encoding='utf8')
        for i in f:
            data = i.strip()
            setup = i.split()
            hc.append(setup)
        f.close()
    except:
        pass
    return hc

def readp():
    hcp=[]
    try:
        f=open('pronoun.txt','r',encoding='utf8')
        for i in f:
            data = i.strip()
            hcp.append(data)
        f.close()
    except:
        pass
    return hcp

def readta():
    hcta=[]
    try:
        f=open('English.txt','r',encoding='utf8')
        for i in f:
            data = i.strip()
            hcta.append(data)
        f.close()
    except:
        pass
    return hcta    

def readtv():
    hctv=[]
    try:
        f=open('Vietnamese.txt','r',encoding='utf8')
        for i in f:
            data = i.strip()
            hctv.append(data)
        f.close()
    except:
        pass
    return hctv  

def addpronoun():
    word1 = Answer.get()
    pronoun(word1)
    showp()
    
def add():
    word = English.get()
    Tu = Vietnam.get()
    Nghia = English.get() +' : '+ Vietnam.get()
    English1(word)
    VietNam1(Tu)
    Fusion(Nghia)
    show()
    
def showp():
    hcp = readp()
    listbox.delete(0,END)
    for i in hcp:
        listbox.insert(END,i)
def show():
    hc= read()
    listbox.delete(0,END)
    for i in hc:
        listbox.insert(END,i)
def showta():
    butt =Button(win,text='Trả lời',command=tra_loi1).grid(row=9,column=0)
    hcta = readta()
    an = random.choice(hcta)
    hcass=showtv1(an)
    listbox.delete(0,END)
    for i in hcass:
        listbox.insert(END,i)    
    

def showtv1(an):
    hctv = readtv()
    hcta = readta()
    b = an
    k=[]
    k.append(an)
    f=open('Answer.txt','a',encoding='utf8')
    f.writelines("\n")
    f.writelines(b)
    f.close()
    return k  

def showtv():
    butt =Button(win,text='Trả lời',command=tra_loi).grid(row=9,column=0)
    hctv = readtv()
    an = random.choice(hctv)
    hcass=showtv1(an)
    listbox.delete(0,END)
    for i in hcass:
        listbox.insert(END,i)

def tra_loi1():
    hcta= readta()
    hc = read()
    k=[]
    file=open('Answer.txt','r',encoding='utf8')
    for tra in file:
        k.append(tra)
    file.close()
    number = len(k)
    b = k[number-1]
    print(b)
    
    count = 0    
    for i in b:
        print(i)
        if(i==" "):
            count = count +1
    
    answer = Answer.get()
    answer = answer.replace(" ","")
    words = ""
    word_true = ""
    count = count + 1
    print(count)
    c = b.replace(" ","")
    print(c+"2")
    for i in range(len(hc)):
        for f in range(len(hc[i])):
            for a in range(count):
                try:
                    words = words+hc[i][f+a]
                    if(a == count -1):
                        if(words==c):
                            words = ""
                            for g in range(f+count,len(hc[i])):
                                    word_true = word_true + hc[i][g]
                        else:
                            words = ""
                except:
                    continue
    word_true = word_true.replace(":","")
    if(answer == word_true):
        Label(win,text='correct ').grid(row=9,column=1)
    else:
        Label(win,text='again ').grid(row=9,column=1)
    return b
    
    
def tra_loi():  
    hctv= readtv()
    hc = read()
    k=[]
    file=open('Answer.txt','r',encoding='utf8')
    for tra in file:
        k.append(tra)
    file.close()
    number = len(k)
    b = k[number-1]
    answer = Answer.get()
    answer = answer.replace(" ","")
    count = 0    
    for i in b:
        print(i)
        if(i==" "):
            count = count +1
    words = ""
    word_true = ""
    count = count + 1
    c = b.replace(" ","")
    for i in range(len(hc)):
        for f in range(len(hc[i])):
            for a in range(count):
                try:
                    words = words+hc[i][f+a]
                    if(a == count-1):
                        if(words==c):
                            words = ""
    #                         trừ 1 nếu như là " : "
                            for k in range(f-1):
                                    word_true = word_true + hc[i][k]
                                    
                        else:
                            words = ""
                except:
                    continue
    
    if(answer == word_true):
        Label(win,text='correct ').grid(row=9,column=1)
    else:
        Label(win,text='again ').grid(row=9,column=1)
    print(word_true)
    return b
win = Tk()
Answer = StringVar()
English = StringVar()
Vietnam = StringVar()
win.title("Learn English")
win.geometry('500x500')
# thay đổi kích thước
# win['bg'] = 'color'  chỉnh sửa background
win.attributes('-topmost',True)
# đè lên cửa sổ khác
name = Label(win, text = "Cách học của Kaloc_2",width=25,fg='red').grid(row = 0) # font = ("Times new Roman",14)
#tên tiêu đề

Label(win,text='Tiếng Anh: ').grid(row=2,column=0)
Entry(win,width=40,textvariable =English).grid(row=2,column=1)
Label(win,text='Tiếng Việt: ').grid(row=3,column=0)
Entry(win,width=40,textvariable =Vietnam).grid(row=3,column=1)
butt =Button(win,text='Thêm',command=add).grid(row=4,column=1)
name = Label(win, text = "Những từ cần nhớ hôm nay: ",width=25,fg='red').grid(row = 5)
# font = ("Times new Roman",14)
listbox = Listbox(win,height=20,width=90)
listbox.grid(row=6,columnspan=2)
show()
button=Frame(win)
button1=Frame(win)
Button(button1,text='Làm bằng TA',command=showta).pack(side=RIGHT)
Button(button1,text='Làm bằng TV',command=showtv).pack(side=RIGHT)
Button(button,text='Phát âm sai',command = addpronoun).pack(side=LEFT)
Button(button,text='Bài chưa xong').pack(side=LEFT)
Button(button1,text='Ôn tập lại tất cả').pack(side=RIGHT)
button.grid(row=7,column=1)
button1.grid(row=7,column=0)
Label(win,text='Điền đáp án: ').grid(row=8,column=0)
Entry(win,width=40,textvariable =Answer).grid(row=8,column=1)



win.mainloop()

# %%
import os
os.remove('Answer.txt')

# %%
from tkinter import *
  
  
# Creating the root window
root = Tk()
  
# Creating a Listbox and
# attaching it to root window
listbox = Listbox(root)
  
# Adding Listbox to the left
# side of root window
listbox.pack(side = LEFT, fill = BOTH)
  
# Creating a Scrollbar and 
# attaching it to root window
scrollbar = Scrollbar(root)
  
# Adding Scrollbar to the right
# side of root window
scrollbar.pack(side = RIGHT, fill = BOTH)
  
# Insert elements into the listbox
for values in range(100):
    listbox.insert(END, values)
      
# Attaching Listbox to Scrollbar
# Since we need to have a vertical 
# scroll we use yscrollcommand
listbox.config(yscrollcommand = scrollbar.set)
  
# setting scrollbar command parameter 
# to listbox.yview method its yview because
# we need to have a vertical view
scrollbar.config(command = listbox.yview)
  
root.mainloop()
